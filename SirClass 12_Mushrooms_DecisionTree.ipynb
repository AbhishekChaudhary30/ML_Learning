# %%
# "mushrooms.csv" data for practice after "diabetes.csv".

# %%
import pandas as pd
import numpy as py
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import os
import warnings

warnings.filterwarnings('ignore')
print('All files Imported Successfully..............')
# Out:
# All files Imported Successfully..............

# %%
df = pd.read_csv('mushrooms.csv')
df.head(3)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# ...

# %%
# In this data, all data is other format so here we have to meeting with manager than start working, means what is a, b, c,...........

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.describe(include = "all")
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %% [markdown]
# Q. what type of ML models perform best on this dataset?
#
# [first thing find target.]

# %% [markdown]
# EDA

# %%
df['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %% [markdown]
# class p represent poisonous mushroom and class e represent ediable mushroom species.

# %%
df['class'].value_counts()
# Out:
# class
# e    4208
# p    3916
# Name: count, dtype: int64

# %%
sns.countplot(x = 'class', data = df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
count = df['class'].value_counts()
plt.figure(figsize = (8,7))
sns.barplot(x = count.index, y = count.values, alpha = 0.8, palette = 'prism')
plt.ylabel('Count', fontsize = 12)
plt.xlabel('Class', fontsize = 12)
plt.title('Number of poisonous/edible mushrooms')
plt.show()

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
def feature_class_plot(hue, features):
    for i, col in enumerate(features.columns):
        plt.figure(i)
        plt.figure(figsize = (10,8))
        ax = sns.countplot(x = df[col], hue = hue, data = df)

# %%
hue = df['class']
features = df.drop('class', axis = 1)
feature_class_plot(hue, features)

# %% [markdown]
# Converting Categorical data using Label Encoder

# %%
df = df.astype('category')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for column in df.columns:
    df[column] = le.fit_transform(df[column])

# %%
df.head(3)
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# ...

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %% [markdown]
# Feature Selection

# %%
df['veil-type'].unique()
# Out:
# array([0])

# %% [markdown]
# The column 'veil-type' is 0 and not contributing to the data so we'll remove it.

# %%
df = df.drop(['veil-type'], axis = 1)

# %% [markdown]
# Checking correlation between features.

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
plt.figure(figsize = (18,16))
sns.heatmap(df.corr(), linewidths = .1, cmap = 'Purples', annot = True)
# Out:
# <Axes: >

# %% [markdown]
# Checking Multicollinearity between features using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X = df.drop(columns = ['class'])  # X is Input.
Y = df['class']                   # Y is Output.

# %%
vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['Features'] = X.columns
vif
# Out:
#            vif                  Features
# 0     5.463186                 cap-shape
# 1     3.904712               cap-surface
# 2     5.950600                 cap-color
# 3     7.984231                   bruises
# 4     8.918271                      odor
# 5   256.122838           gill-attachment
# 6     4.534113              gill-spacing
# 7     5.758180                 gill-size
# 8     6.284702                gill-color
# 9     9.243136               stalk-shape
# 10    8.129864                stalk-root
# 11   11.707764  stalk-surface-above-ring
# 12   11.768772  stalk-surface-below-ring
# 13   17.163156    stalk-color-above-ring
# 14   17.215182    stalk-color-below-ring
# 15  280.123888                veil-color
# 16   65.370463               ring-number
# 17   13.429124                 ring-type
# 18   16.937589         spore-print-color
# 19   21.434074                population
# 20    2.800932                   habitat

# %%
df.shape
# Out:
# (8124, 22)

# %% [markdown]
# We can see that gill-attachment, veil-color, ring-number, population, spore-print-color has high collinearity.
#
# On basis of Correlation and multicollinearity we can now remove Ring-tye, bruises, veil-color, spore-print-color, ring-number, gill-attachment, population.

# %%
df = df.drop(['veil-color', 'ring-type', 'bruises', 'spore-print-color', 'ring-number', 'gill-attachment'], axis = 1)

# %%
df.shape
# Out:
# (8124, 16)

# %% [markdown]
# Checking Heatmap after removing some outliers

# %%
plt.figure(figsize = (18,16))
sns.heatmap(df.corr(), linewidths = .1, cmap = 'coolwarm', annot = True)
# Out:
# <Axes: >

# %%
# Checking multicollinearity after removal of feature

vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['Features'] = X.columns
vif
# Out:
#            vif                  Features
# 0     5.463186                 cap-shape
# 1     3.904712               cap-surface
# 2     5.950600                 cap-color
# 3     7.984231                   bruises
# 4     8.918271                      odor
# 5   256.122838           gill-attachment
# 6     4.534113              gill-spacing
# 7     5.758180                 gill-size
# 8     6.284702                gill-color
# 9     9.243136               stalk-shape
# 10    8.129864                stalk-root
# 11   11.707764  stalk-surface-above-ring
# 12   11.768772  stalk-surface-below-ring
# 13   17.163156    stalk-color-above-ring
# 14   17.215182    stalk-color-below-ring
# 15  280.123888                veil-color
# 16   65.370463               ring-number
# 17   13.429124                 ring-type
# 18   16.937589         spore-print-color
# 19   21.434074                population
# 20    2.800932                   habitat

# %% [markdown]
# Machine Learning Algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score

# %%
# X = df.drop('class', axis = 1) # we write above so not write again.
# Y = df['class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state = 42, test_size = 0.25)
print('Training feature matrix size: ', X_train.shape)
print('Training target vector size: ', Y_train.shape)
print('Test feature matrix size: ', X_test.shape)
print('Test target vector size: ', Y_test.shape)
# Out:
# Training feature matrix size:  (6093, 21)
# Training target vector size:  (6093,)
# Test feature matrix size:  (2031, 21)
# Test target vector size:  (2031,)

# %%
maxAccu = 0
maxRS = 0
for i in range(1,250):
    X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.33, random_state = i)
    log_reg = LogisticRegression()
    log_reg.fit(X_train, Y_train)
    y_pred = log_reg.predict(X_test)
    acc = accuracy_score(Y_test, y_pred)
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
print('Best accuracy is', maxAccu, 'on Random_State', maxRS)
# Out:
# Best accuracy is 0.9597165236851921 on Random_State 167

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state = 167, test_size = 0.33)
log_reg = LogisticRegression()
log_reg.fit(X_train, Y_train)
y_pred = log_reg.predict(X_test)

print(classification_report(Y_test, y_pred))

print('Logistics Regression Evaluation')
print('\n')
print('Accuracy Score of Logistic Regression :', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistic Regression : '+'\033[0m \n', confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistic Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      1424
#            1       0.96      0.95      0.96      1257
#
#     accuracy                           0.96      2681
#    macro avg       0.96      0.96      0.96      2681
# weighted avg       0.96      0.96      0.96      2681
#
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistic Regression : 0.9597165236851921
#
#
# Confusion matrix of Logistic Regression :
#  [[1376   48]
#  [  60 1197]]
#
#
# classification Report of Logistic Regression
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      1424
#            1       0.96      0.95      0.96      1257
#
#     accuracy                           0.96      2681
#    macro avg       0.96      0.96      0.96      2681
# weighted avg       0.96      0.96      0.96      2681

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(X_train, Y_train)
# Out:
# 1.0

# %%
dtc.score(X_test, Y_test)
# Out:
# 1.0

# %%
dtc1 = DecisionTreeClassifier(criterion = 'entropy')
dtc1.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dtc1.score(X_train, Y_train)
# Out:
# 1.0

# %%
dtc1.score(X_test, Y_test)
# Out:
# 1.0

# %%
dtc2 = DecisionTreeClassifier(criterion = 'entropy', max_depth = 3)
dtc2.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
dtc2.score(X_train, Y_train)
# Out:
# 0.9566415579643579

# %%
dtc2.score(X_test, Y_test)
# Out:
# 0.95822454308094

# %%
y_pred = dtc.predict(X_test)

# %%
print('Confusion matrix: ', confusion_matrix(Y_test, y_pred))
# Out:
# Confusion matrix:  [[1424    0]
#  [   0 1257]]

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1424
#            1       1.00      1.00      1.00      1257
#
#     accuracy                           1.00      2681
#    macro avg       1.00      1.00      1.00      2681
# weighted avg       1.00      1.00      1.00      2681

# %%
print(classification_report(Y_test, dtc1.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1424
#            1       1.00      1.00      1.00      1257
#
#     accuracy                           1.00      2681
#    macro avg       1.00      1.00      1.00      2681
# weighted avg       1.00      1.00      1.00      2681

# %%
print(classification_report(Y_test, dtc2.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      1424
#            1       0.94      0.97      0.96      1257
#
#     accuracy                           0.96      2681
#    macro avg       0.96      0.96      0.96      2681
# weighted avg       0.96      0.96      0.96      2681

# %%
from sklearn import tree

# %%
plt.figure(figsize = (20,15))
tree.plot_tree(dtc, filled = True, fontsize = 10)
plt.show()

# %%
plt.figure(figsize = (20,15))
tree.plot_tree(dtc1, filled = True, fontsize = 10)
plt.show()

# %%
plt.figure(figsize = (20,15))
tree.plot_tree(dtc2, filled = True, fontsize = 10)
plt.show()

# %%
# We can see that Decision Tree Classifier gives maximum Accuracy so we will continue further investigation.

# %%
# Cross Validation -:

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(dtc, X, Y, cv = 6)
print('\033[1m'+'Cross Validation Score Decision Tree Classifier : '+'\033[0m\n')
print('Score :', score)
print('Mean Score :', score.mean())
print('Std deviation :', score.std())
# Out:
# Cross Validation Score Decision Tree Classifier :
#
# Score : [0.81093058 1.         1.         1.         1.         0.67651403]
# Mean Score : 0.914574101427868
# Std deviation : 0.1268890022523258

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(log_reg, X, Y, cv = 6)
print('\033[1m'+'Cross Validation Score Logistic Regression : '+'\033[0m\n')
print('Score :', score)
print('Mean Score :', score.mean())
print('Std deviation :', score.std())
# Out:
# Cross Validation Score Logistic Regression :
#
# Score : [0.64771049 0.97710487 0.92836041 0.91728213 0.97710487 0.82644018]
# Mean Score : 0.8790004923682915
# Std deviation : 0.11504236758964963

# %%
# Hyper Paramater Tuning -: GridSearchCV (used for one algo) (for two algos --> Randomized Search CV)
      # It is used in DT algo and Random forest algo(GridSearchCV).
